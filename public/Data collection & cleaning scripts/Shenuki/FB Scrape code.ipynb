# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd

# URL of the target Facebook page
target_url = "https://www.facebook.com"

# Initialize the Chrome WebDriver
driver = webdriver.Chrome()

# Navigate to Facebook and log in
driver.get(target_url)
username = driver.find_element(By.ID, 'email')
password = driver.find_element(By.ID, 'pass')
username.send_keys('shenuki101@gmail.com')
password.send_keys('chesterperera')
password.send_keys(Keys.RETURN)

# Allow some time for the login to complete and CAPTCHA to appear
time.sleep(5)

# Wait for manual CAPTCHA solving
input("Press Enter after solving the CAPTCHA...")

# Navigate to the desired page or group
driver.get('https://www.facebook.com/search/posts?q=renewable%20energy%20target%20australia')

# Allow some time for the page to load
time.sleep(5)

# Initialize empty lists to store the extracted posts and comments
posts = []
comments = []

# Loop to scroll the page and collect posts
for _ in range(100):
    # Scroll the page
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    time.sleep(2)  # Adjust sleep time as necessary to allow for page load

    # Get the page source
    resp = driver.page_source

    # Parse the page source with BeautifulSoup
    soup = BeautifulSoup(resp, 'html.parser')

    # Find the specific divs containing the required information
    items = soup.find_all('div', {'class': 'x78zum5 xdt5ytf xz62fqu x16ldp7u'})

    # Iterate through each item and extract the desired information
    for item in items:
        post_content = item.get_text()
        if "renewable energy" in post_content.lower() and post_content not in posts:
            posts.append(post_content)
            if len(posts) == 10:
                break
    if len(posts) >= 10:
        break

# Function to scroll and scrape comments for a specific post
def scrape_comments():
    # Get the page source
    resp = driver.page_source

    # Parse the page source with BeautifulSoup
    soup = BeautifulSoup(resp, 'html.parser')

    # Find the specific divs containing the comments
    comments_section = soup.find_all('div', {'class': 'x1o1ewxj x3x9cwd x1e5q0jg x13rtm0m x78zum5 xdt5ytf x1iyjqo2 x1al4vs7'})
    post_comments = []
    for comment in comments_section:
        comment_text = comment.get_text()
        if comment_text:
            post_comments.append(comment_text)

    return post_comments

# Loop through the collected posts to scrape comments
for idx, post in enumerate(posts):
    print(f"Post {idx + 1}: {post}")
    
    # Pause the script to allow manual opening of comments
    input("Press Enter after opening the comments for the post...")

    # Scroll and wait for comments to load
    for _ in range(10):
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        time.sleep(2)  # Adjust sleep time as necessary to allow for comments to load

    # Scrape comments for the current post
    post_comments = scrape_comments()
    comments.append(post_comments)
    print("Comments collected. You can now close the comments section.")

    # Print comments for the current post
    if post_comments:  # Check if there are comments
        print("Comments:")
        for comment in post_comments:
            print(comment)
    else:
        print("No comments found for this post.")
    
    # Print a message to let you know to close the comments
    input("Press Enter after closing the comments for the post...")


# Prepare data for CSV export
data = []
for idx, content in enumerate(posts):
    if idx < len(comments):  # Ensure there's a comment entry
        for comment in comments[idx]:
            data.append([content, comment])
    else:
        data.append([content, None])

# Create a DataFrame and save it to CSV
df = pd.DataFrame(data, columns=['Post', 'Comment'])
df.to_csv('australia_renewable_FB2.csv', index=False)

print("Data has been saved to australia_renewable.csv")
# Out:
# Press Enter after solving the CAPTCHA...
# Post 1: Refurbishing our coal plants to extend their working life, scrapping the renewable energy target and ramping up gas exploration is the simplest solution to Australia's power demands in the immediate years to come, writes SkyNews.com.au contributor Gideon Rozner.
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# No comments found for this post.
# Press Enter after closing the comments for the post...
# Post 2: Barnaby Joyce has refused to commit the government to maintain the Renewable Energy Target, after a report that conservative Coalition MPs want to ditch it if the United States pulls out of the Paris climate agreement.
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# No comments found for this post.
# Press Enter after closing the comments for the post...
# Post 3: Barnaby Joyce won't rule out dumping Renewable Energy TargetDeputy prime minister criticises ‘romantic’ targets set by states as some Coalition MPs call to ditch RET if US pulls out of Paris climate deal
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# No comments found for this post.
# Press Enter after closing the comments for the post...
# Post 4: Coalition ministers are defending the Government's renewable energy target following criticism from former prime minister Tony Abbott, who has accused them of taking the public for "mugs" and losing touch with voters. ABC News | http://ab.co/2jLENZg
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# No comments found for this post.
# Press Enter after closing the comments for the post...
# Post 5: Government defends renewable energy target after Abbott criticismCoalition ministers are defending the Government's renewable energy target following criticism from former prime minister Tony Abbott.
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# No comments found for this post.
# Press Enter after closing the comments for the post...
# Post 6: South Australia has hit its 50% renewable energy target 8 years early! In the last year, 53% of SA’s energy has been generated by wind and solar infrastructure. Read more: https://goo.gl/c9vAmH
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# No comments found for this post.
# Press Enter after closing the comments for the post...
# Post 7: SA has already reached its 2025 renewable energy targetSouth Australia hits its 50 per cent renewable energy target years ahead of schedule.
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# Comments:
# The Conversation Australia + NZ's  Conversation Australia + NZ Verified account  · Follow  · Shared with PublicAfter months of deadlock, a deal has finally been reached to reduce the Renewable Energy Target, ending the uncertainty for industry but also risking an already sparse pipeline of future projects. We asked the experts how the reduced Renewable Energy Target will affect investment. This is what they said.theconversation.comHow will the reduced Renewable Energy Target affect investment?The deal will see the RET wound back to 33,000 gigawatt hours of renewable energy by 2020, down from its previous level of 41,000 GWh.FacebookFacebookFacebookFacebookFacebookFacebookFacebookFacebookFacebookFacebookFacebookAll reactions:66 669 comments21 sharesLikeCommentSendShareMost relevant﻿Jakob AnderssonLast I heard was that labor agreed under the condition that they can change it after the next election when they win. In which case with the current philistines in charge, a compromise was the best they could ever hope for and much better than continued uncertainty. There is no way the liberals will win the next election, so expect to see better legislation in 2016.9yLikeReply5View all 4 repliesTop fanPaul RichardsWhat a sad bunch of uninformed fools our political centre of gravity is. Their time value is emerging generations only hope...9yLikeReplyEdited9Bat MelSo proud to be Australian right now.9yLikeReplyView 1 replyDaimo ButlerThe consequences of denierrhea and the crappy voting decisions of the Ochlocracy.9yLikeReply4Write a comment…
# Press Enter after closing the comments for the post...
# Post 8: Ambitious renewable energy investment drives from state governments mean Australia can boost its 2030 emissions reduction target ahead of the United Nations climate summit in Glasgow without the federal government making any new commitments. | Mike Foley #COP26
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# Comments:
# Adam Bandt's  Bandtvia Ellen Sandell MP  · Shared with PublicWhich would you rather -- your government to make decisions on climate change based on a report written by the world's leading climate scientists, or based on one written by their ol' mate Dick from the corporate boardrooms of Australia? We know which we'd rather. A-Team. theconversation.comFinally, some light relief for the Renewable Energy TargetThe Australian government has just received a vitally important report to guide their decisions on the future of Australia’s Renewable Energy Target (RET). But it’s not the RET review report of the Coalition-appointed…FacebookFacebookFacebookFacebookFacebookFacebookFacebookFacebookFacebookFacebookFacebookAll reactions:882 88242 comments105 sharesLikeCommentSendShareMost relevant﻿Nicole RowRowI would like all of our representatives to use independent verifiable evidence that has been critically peer reviewed even when it is not the politically popular thing to do. I am very pleased that the Greens take this position too and look to the long term best interests of the planet and all its inhabitants. We need more Greens votes to shake up our political landscape10yLikeReply36James KeaneCorporate boardrooms obviously! The reason they don't care is that they won't be around in 30 years to suffer the consequences.10yLikeReply15View 1 replyAnthony ShawHow about a new government, is that option 3?10yLikeReply5Alecia ChristyThe instant "EXPERT" is an apalling development.. The "Instant Expert' to expound a view that has been propounded by the persons wanting to legitimise unreasonable, and even untrue hypotheses.  Most frequently active in the preparation of "Enviromental Impact Reports" usually for Mining conglomerates!!!!  The all new version of the "MODERN FAIRY TALES"...  ..    It has been elevated to new heights by Political Parties to validate their dishonesty, and confuse electors. "Complex matter" is a phrase which means  "Wait for the bullsh...t"10yLikeReply2Anthony HeinemannYou know what? Apart from all the climate issues, what type of government does not want to invest in new technologies, new jobs, and reducing pollution? Who the hell elected these morons?10yLikeReply2Chris HenryGet rid of wind farms would be a good start10yLikeReplyDennis Vranicyou mean like the fudged figures from the BOM???10yLikeReplyView all 4 repliesKristian MacePs . Tesla invented free energy 100 years ago10yLikeReplyAnne BeaumontWhy doesn't this government want to have a Science mininster or fund research - because they don't like the truths it tells.10yLikeReplyJillian VerhardtI hope this does not result in another 'hybrid' satisfying neither end of a simple equation!  It is good to make an agreement, however, history often shows compromised Intentions fail to address the underlying, nor set a course for the future.10yLikeReplyWrite a comment…
# Press Enter after closing the comments for the post...
# Post 9: Labor’s 50% renewable energy target and 45% emissions reduction target will put up power prices for Australian families and small businesses.Don't Risk It!
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# No comments found for this post.
# Press Enter after closing the comments for the post...
# Post 10: ShenukiLabor’s 50% renewable energy target and 45% emissions reduction target will put up power prices for Australian families and small businesses.
#
# Don't Risk It!
# Press Enter after opening the comments for the post...
# Comments collected. You can now close the comments section.
# No comments found for this post.
# Press Enter after closing the comments for the post...
# Data has been saved to australia_renewable.csv
